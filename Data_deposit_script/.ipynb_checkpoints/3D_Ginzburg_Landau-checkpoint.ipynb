# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# Given constants
n = 8
d = n**3
h = 1 / (n + 1)
λ = 0.01
β = 1 / 10
dt = 0.002
N = int(1/dt)  # Interested in T = 1
dt = 1/N  # Correct for small deviation

BATCH_SIZE = 100  # Set your desired batch size

data_path = f"./Saved_Data/3D_GZ_data_d_{d}.npz"

# Hyperparameters
hyperparameters = {
    "d": d,
    "h": h,
    "λ": λ,
    "β": β,
    "dt": dt,
    "N": N,
    "BATCH_SIZE": BATCH_SIZE
}

# Create directory if it doesn't exist
if not os.path.exists("./Saved_Data"):
    os.makedirs("./Saved_Data")

# Load existing data or initialize
if os.path.exists(data_path):
    with np.load(data_path) as data:
        all_samples = data['samples']
else:
    all_samples = np.empty((0, n + 2, n + 2, n + 2))

def V_grad_periodic(U):
    """
    Compute the gradient of the potential energy V for a periodic domain.
    
    Args:
    - U (np.ndarray): Input tensor for which the gradient is computed.
    
    Returns:
    - np.ndarray: Gradient of the potential energy V.
    """
    return (λ / h**2) * (
        6*U - np.roll(U, 1, axis=1) - np.roll(U, -1, axis=1) 
        - np.roll(U, -1, axis=2) - np.roll(U, 1, axis=2)
        - np.roll(U, -1, axis=3) - np.roll(U, 1, axis=3)
    ) - np.pi*np.sin(np.pi*U) / (4*λ)

def V_grad(U):
    """
    Compute the gradient of the potential energy V for a periodic domain.
    
    Args:
    - U (np.ndarray): Input tensor for which the gradient is computed.
    
    Returns:
    - np.ndarray: Gradient of the potential energy V.
    """
    return (λ / h**2) * (
        6*U - np.roll(U, 1, axis=1) - np.roll(U, -1, axis=1) 
        - np.roll(U, -1, axis=2) - np.roll(U, 1, axis=2)
        - np.roll(U, -1, axis=3) - np.roll(U, 1, axis=3)
    ) - U * (1 - U**2) /λ

count = 0


for iteration in range(600):

    U = np.zeros((BATCH_SIZE, n + 2, n + 2, n + 2))  # Initialize at each iteration

    # Creating samples for 1D Ginzburg Landau
    for _ in range(N):
        dW = np.sqrt(dt) * np.random.randn(BATCH_SIZE, n + 2, n + 2, n + 2)
        U[:, 1:-1, 1:-1, 1:-1] += (-V_grad(U)[:, 1:-1, 1:-1, 1:-1] * dt + np.sqrt(2/β) * dW[:, 1:-1, 1:-1, 1:-1])
        count += np.sum(U > 2.5) + np.sum(U <-2.5)
        U[U > 2.5] = 2.5
        U[U < -2.5] = -2.5
    all_samples = np.concatenate((all_samples, U), axis=0)
    print(f'Saved data at iteration {iteration}, total violation is {count}')

    # Save the accumulated data
    np.savez(data_path, samples=all_samples, hyperparameters=hyperparameters)

# Visualization of the 8-th marginal distribution
eighth_samples = all_samples[:, 4, 4, 4]  # Extract the 4-th bit from each sample
plt.hist(eighth_samples, bins=50, density=True)
plt.title("(4,4,4)-th Marginal Distribution")
plt.show()
# Out:
# Saved data at iteration 0, total violation is 0
# Saved data at iteration 1, total violation is 0
# Saved data at iteration 2, total violation is 0
# Saved data at iteration 3, total violation is 0
# Saved data at iteration 550, total violation is 0
# Saved data at iteration 551, total violation is 0
# Saved data at iteration 552, total violation is 0
# Saved data at iteration 553, total violation is 0
# Saved data at iteration 554, total violation is 0
# Saved data at iteration 555, total violation is 0
# Saved data at iteration 556, total violation is 0
# Saved data at iteration 557, total violation is 0
# Saved data at iteration 558, total violation is 0
# Saved data at iteration 559, total violation is 0
# Saved data at iteration 560, total violation is 0
# Saved data at iteration 561, total violation is 0
# Saved data at iteration 562, total violation is 0
# Saved data at iteration 563, total violation is 0
# Saved data at iteration 564, total violation is 0
# Saved data at iteration 565, total violation is 0
# Saved data at iteration 566, total violation is 0
# Saved data at iteration 567, total violation is 0
# Saved data at iteration 568, total violation is 0
# Saved data at iteration 569, total violation is 0
# Saved data at iteration 570, total violation is 0
# Saved data at iteration 571, total violation is 0
# Saved data at iteration 572, total violation is 0
# Saved data at iteration 573, total violation is 0
# Saved data at iteration 574, total violation is 0
# Saved data at iteration 575, total violation is 0
# Saved data at iteration 576, total violation is 0
# Saved data at iteration 577, total violation is 0
# Saved data at iteration 578, total violation is 0
# Saved data at iteration 579, total violation is 0
# Saved data at iteration 580, total violation is 0
# Saved data at iteration 581, total violation is 0
# Saved data at iteration 582, total violation is 0
# Saved data at iteration 583, total violation is 0
# Saved data at iteration 584, total violation is 0
# Saved data at iteration 585, total violation is 0
# Saved data at iteration 586, total violation is 0
# Saved data at iteration 587, total violation is 0
# Saved data at iteration 588, total violation is 0
# Saved data at iteration 589, total violation is 0
# Saved data at iteration 590, total violation is 0
# Saved data at iteration 591, total violation is 0
# Saved data at iteration 592, total violation is 0
# Saved data at iteration 593, total violation is 0
# Saved data at iteration 594, total violation is 0
# Saved data at iteration 595, total violation is 0
# Saved data at iteration 596, total violation is 0
# Saved data at iteration 597, total violation is 0
# Saved data at iteration 598, total violation is 0
# Saved data at iteration 599, total violation is 0

# %%
# Calculate two-point correlation
from copy import deepcopy
def two_pt_correlation(sample, dim):
    r'''
    Calculate the two pt correlation between target_dimension and every other dimension in the data
    '''
    data_dim = deepcopy(sample[:, dim].reshape(-1, 1))
    data_all = deepcopy(sample)
    data_dim = data_dim - np.mean(data_dim, axis = 0, keepdims = True)
    data_all = data_all - np.mean(data_all, axis = 0, keepdims = True)
    std_all = np.sqrt(np.mean(np.power(data_all, 2), axis = 0))
    std_dim = std_all[dim]
    correlation = 1/data_all.shape[0]*data_all.T@data_dim/(np.outer(std_all, std_dim))

    return correlation

dim_3d = n
col1 = interlace(int(dim_2d/2) - 1, int(dim_2d/2) - 1, 4)
true_correlation = np.zeros([dim_2d,dim_2d])
true_correlation_interlaced = two_pt_correlation(y_3d, dim=col1)
for i in range(dim_2d):
    for j in range(dim_2d):
        true_correlation[i, j] = true_correlation_interlaced[interlace(i, j, l = L)]

plt.imshow(true_correlation, aspect='auto', cmap='viridis')

# %%
plt.scatter(all_samples[:, 4, 4, 4], all_samples[:, 4, 6, 4])
